# %%
class User:
    def __init__(self, username, name, email):
        self.username = username
        self.name = name
        self.email = email
        print('User created!')

# %%
user1 = User('username1', 'User', 'user1@mail.com')
# Out:
# User created!

# %%
user1
