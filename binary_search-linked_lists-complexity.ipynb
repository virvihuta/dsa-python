# %%
cards = [13, 11, 10, 7, 4, 3, 2, 1, 0]
query = 7
output = 3

# %%
def locate_cards(cards, query):
    pass

# %%
result = locate_cards(cards, query)
result == output
# Out:
# False

# %%
test = {
    'input': {
        'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0],
        'query': 7
    },
    'output': 3
}

# %%
locate_cards(test['input']['cards'], test['input']['query'])

# %%
tests = []

# %%
# query occours in the middle of the list

tests.append(test)

tests.append({ 
    'input': {
        'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0],
        'query': 1
    }, 
    'output': 7
})

# %%
# query occours in the beginning of the list

tests.append({
    'input': {
        'cards': [4, 2, 1, -1],
        'query': 4
    },
    'output': 0
})

# %%
# query is the last element

tests.append({
    'input': {
        'cards': [3, -1, -9, -127],
        'query': -127
    },
    'output': 3
})

# %%
# cards containts just one element

tests.append({
    'input': {
        'cards': [6],
        'query': 6
    },
    'output': 0
})

# %%
# cards does not contain query

tests.append({
    'input': {
        'cards': [9, 7, 5, 2, -9],
        'query': 4
    },
    'output': -1
})

# %%
# cards is empty

tests.append({
    'input': {
        'cards': [],
        'query': 7
    },
    'output': -1
})

# %%
# numbers can repeat in cards

tests.append({
    'input': {
        'cards': [8, 8, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0],
        'query': 3
    },
    'output': 7
})

# %%
# query can repeat in cards

tests.append({
    'input': {
        'cards': [8, 8, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0],
        'query': 6
    },
    'output': 2
})

# %%
print(tests)
# Out:
# [{'input': {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 7}, 'output': 3}, {'input': {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 1}, 'output': 7}, {'input': {'cards': [4, 2, 1, -1], 'query': 4}, 'output': 0}, {'input': {'cards': [3, -1, -9, -127], 'query': -127}, 'output': 3}, {'input': {'cards': [6], 'query': 6}, 'output': 0}, {'input': {'cards': [9, 7, 5, 2, -9], 'query': 4}, 'output': -1}, {'input': {'cards': [], 'query': 7}, 'output': -1}, {'input': {'cards': [8, 8, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0], 'query': 3}, 'output': 7}, {'input': {'cards': [8, 8, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0], 'query': 6}, 'output': 2}]

# %%
# linear search algorithm

def locate_cards(cards, query):
    position = 0

    while True:

        if cards[position] == query:
            return position
        
        position = position + 1

        if position == len(cards):
            return -1

# %%
test
# Out:
# {'input': {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 7}, 'output': 3}

# %%
result = locate_cards(test['input']['cards'], test['input']['query'])
result
# Out:
# 3

# %%
result == output
# Out:
# True

# %%
from jovian.pythondsa import evaluate_test_cases

evaluate_test_cases(locate_cards, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 1}
#
# Expected Output:
# 7
#
#
# Actual Output:
# 7
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [4, 2, 1, -1], 'query': 4}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': -127}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [6], 'query': 6}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [9, 7, 5, 2, -9], 'query': 4}
#
# Expected Output:
# ...

# %%
def locate_cards(cards, query):
    position = 0

    print(cards)
    print(query)

    while True:
        print(position)
        if cards[position] == query:
            return position
        
        position = position + 1

        if position == len(cards):
            return -1

# %%
cards6 = tests[6]['input']['cards']
query6 = tests[6]['input']['query']

locate_cards(cards6, query6)
# Out:
# []
# 7
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[93], line 4
#       1 cards6 = tests[6]['input']['cards']
#       2 query6 = tests[6]['input']['query']
# ----> 4 locate_cards(cards6, query6)
#
# Cell In[92], line 9, in locate_cards(cards, query)
#       7 while True:
#       8     print(position)
# ----> 9     if cards[position] == query:
#      10         return position
#      12     position = position + 1
#
# IndexError: list index out of range

# %%
def locate_cards(cards, query):
    position = 0

    while position < len(cards):
        if cards[position] == query:
            return position
        position += 1

    return -1

# %%
evaluate_test_cases(locate_cards, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 1}
#
# Expected Output:
# 7
#
#
# Actual Output:
# 7
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [4, 2, 1, -1], 'query': 4}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': -127}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [6], 'query': 6}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [9, 7, 5, 2, -9], 'query': 4}
#
# Expected Output:
# ...

# %%
# binary search algorithm

def locate_cards(cards, query):
    low, high = 0, len(cards) - 1

    while low <= high:
        mid = (low + high) // 2
        mid_number = cards[mid]

        print(f"low: {low}, high: {high}, mid: {mid}, mid_number: {mid_number}")

        if mid_number == query:
            return mid
        elif mid_number < query:
            high = mid - 1
        elif mid_number > query:
            low = mid + 1 

    return -1

# %%
evaluate_test_cases(locate_cards, tests)
# Out:
# TEST CASE #0
# low: 0, high: 8, mid: 4, mid_number: 4
# low: 0, high: 3, mid: 1, mid_number: 11
# low: 2, high: 3, mid: 2, mid_number: 10
# low: 3, high: 3, mid: 3, mid_number: 7
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.031 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
# low: 0, high: 8, mid: 4, mid_number: 4
# low: 5, high: 8, mid: 6, mid_number: 2
# low: 7, high: 8, mid: 7, mid_number: 1
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 1}
#
# Expected Output:
# 7
#
#
# Actual Output:
# 7
#
# Execution Time:
# 0.016 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
# low: 0, high: 3, mid: 1, mid_number: 2
# low: 0, high: 0, mid: 0, mid_number: 4
#
# Input:
# {'cards': [4, 2, 1, -1], 'query': 4}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.011 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
# low: 0, high: 3, mid: 1, mid_number: -1
# ...

# %%
def test_location(cards, query, mid):
    mid_number = cards[mid]
    print(f"Mid: {mid}, Mid Number: {mid_number}")
    if mid_number == query:
        if mid-1 >= 0 and cards[mid-1] == query:
            return 'left'
        else:
            return 'found'
    elif mid_number < query:
        return 'left'
    else:
        return 'right'

def locate_cards(cards, query):
    low, high = 0, len(cards) - 1

    while low <= high:
        print(f"Low: {low}, High: {high}")
        mid = (low + high) // 2
        result = test_location(cards, query, mid)

        if result == 'found':
            return mid
        elif result == 'left':
            high = mid - 1
        elif result == 'right':
            low = mid + 1
            
    return -1

# %%
evaluate_test_cases(locate_cards, tests)
# Out:
# TEST CASE #0
# Low: 0, High: 8
# Mid: 4, Mid Number: 4
# Low: 0, High: 3
# Mid: 1, Mid Number: 11
# Low: 2, High: 3
# Mid: 2, Mid Number: 10
# Low: 3, High: 3
# Mid: 3, Mid Number: 7
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.044 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
# Low: 0, High: 8
# Mid: 4, Mid Number: 4
# Low: 5, High: 8
# Mid: 6, Mid Number: 2
# Low: 7, High: 8
# Mid: 7, Mid Number: 1
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 1}
#
# Expected Output:
# 7
#
#
# Actual Output:
# 7
#
# Execution Time:
# 0.028 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
# Low: 0, High: 3
# Mid: 1, Mid Number: 2
# Low: 0, High: 0
# Mid: 0, Mid Number: 4
#
# Input:
# {'cards': [4, 2, 1, -1], 'query': 4}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.039 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
# Low: 0, High: 3
# Mid: 1, Mid Number: -1
# ...

# %%
cards = [13, 11, 10, 7, 4, 3, 2, 1, 0]
query = 7
output = 3

# %%
def binary_search(low, high, condition):
    while low <= high:
        mid = (low + high) // 2
        result = condition(mid)
        if result == 'found':
            return mid
        elif result == 'left':
            high = mid - 1
        else:
            low = mid + 1
    return -1

# %%
def locate_cards(cards, query):
    def condition(mid):
        if cards[mid] == query:
            if mid > 0 and cards[mid - 1] == query:
                return 'left'
            else: 
                return 'found'
        elif cards[mid] < query:
            return 'left'
        else:
            return 'right'
    return binary_search(0, len(cards) - 1, condition)

# %%
evaluate_test_cases(locate_cards, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.005 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 1}
#
# Expected Output:
# 7
#
#
# Actual Output:
# 7
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [4, 2, 1, -1], 'query': 4}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.009 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': -127}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [6], 'query': 6}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [9, 7, 5, 2, -9], 'query': 4}
#
# Expected Output:
# ...
