# %%
cards = [13, 11, 10, 7, 4, 3, 2, 1, 0]
query = 7
output = 3

# %%
def locate_cards(cards, query):
    pass

# %%
result = locate_cards(cards, query)
result == output
# Out:
# False

# %%
test = {
    'input': {
        'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0],
        'query': 7
    },
    'output': 3
}

# %%
locate_cards(test['input']['cards'], test['input']['query'])

# %%
tests = []

# %%
# query occours in the middle of the list

tests.append(test)

tests.append({ 
    'input': {
        'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0],
        'query': 1
    }, 
    'output': 6
})

# %%
# query occours in the beginning of the list

tests.append({
    'input': {
        'cards': [4, 2, 1, -1],
        'query': 4
    },
    'output': 4
})

# %%
# query is the last element

tests.append({
    'input': {
        'cards': [3, -1, -9, -127],
        'query': -127
    },
    'output': 4
})

# %%
# cards containts just one element

tests.append({
    'input': {
        'cards': [6],
        'query': 6
    },
    'output': 0
})

# %%
# cards does not contain query

tests.append({
    'input': {
        'cards': [9, 7, 5, 2, -9],
        'query': 4
    },
    'output': -1
})

# %%
# cards is empty

tests.append({
    'input': {
        'cards': [],
        'query': 7
    },
    'output': -1
})

# %%
# numbers can repeat in cards

tests.append({
    'input': {
        'cards': [8, 8, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0],
        'query': 3
    },
    'output': 7
})

# %%
# query can repeat in cards

tests.append({
    'input': {
        'cards': [8, 8, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0],
        'query': 6
    },
    'output': 2
})

# %%
print(tests)
# Out:
# [{'input': {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 7}, 'output': 3}, {'input': {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 6}, 'output': 6}, {'input': {'cards': [4, 2, 1, -1], 'query': 4}, 'output': 4}, {'input': {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 7}, 'output': 3}, {'input': {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 1}, 'output': 6}, {'input': {'cards': [4, 2, 1, -1], 'query': 4}, 'output': 4}, {'input': {'cards': [3, -1, -9, -127], 'query': -127}, 'output': 4}, {'input': {'cards': [6], 'query': 6}, 'output': 0}, {'input': {'cards': [9, 7, 5, 2, -9], 'query': 4}, 'output': -1}, {'input': {'cards': [], 'query': 6}, 'output': -1}, {'input': {'cards': [], 'query': 7}, 'output': -1}, {'input': {'cards': [8, 8, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0], 'query': 3}, 'output': 7}, {'input': {'cards': [8, 8, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0], 'query': 6}, 'output': 2}]

# %%
# linear search algorithm

def locate_cards(cards, query):
    position = 0

    while True:

        if cards[position] == query:
            return position
        
        position = position + 1

        if position == len(cards):
            return -1

# %%
test
# Out:
# {'input': {'cards': [13, 11, 10, 7, 4, 3, 2, 1, 0], 'query': 7}, 'output': 3}

# %%
result = locate_cards(test['input']['cards'], test['input']['query'])
result
# Out:
# 3

# %%
result == output
# Out:
# True
